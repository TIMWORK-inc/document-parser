# %% [markdown]
# # EasyOCR 예제 (Jupyter Notebook)
# 한국어 + 영어 텍스트 인식을 위한 기본적인 OCR 예제입니다.
# 1. 라이브러리: EasyOCR + OpenCV + matplotlib
# 2. 입력: 이미지 파일
# 3. 출력: 텍스트 및 바운딩 박스 시각화

# %%
# 설치 (필요시)
#!pip install easyocr
#!pip install torch torchvision torchaudio
#!pip install opencv-python-headless matplotlib

# %%
# 라이브러리 임포트
import easyocr
import cv2
from matplotlib import pyplot as plt
from PIL import Image

# %%
# EasyOCR Reader 생성 (한국어 + 영어)
reader = easyocr.Reader(['ko', 'en'])

# %%
# 이미지 경로 설정
image_path = '../docs/dummy_1.png'  # 여기에 본인의 이미지 경로 입력

# %%
# OCR 수행
results = reader.readtext(image_path)

# 결과 출력
for bbox, text, confidence in results:
    print(f'Text: {text}, Confidence: {confidence:.2f}')
# Out:
# Text: Thesis, Confidence: 0.88
# Text: Iypes:, Confidence: 0.98
# Text: ["THEE-sis_, Confidence: 0.95
# Text: 1, Confidence: 0.85
# Text: Expository Thesis, Confidence: 0.83
# Text: thesisis a statement or, Confidence: 0.78
# Text: theory put, Confidence: 1.00
# Text: Analytical Thesis, Confidence: 0.97
# Text: forward to be proved or maintained;, Confidence: 0.71
# Text: typically in academic writing:, Confidence: 0.65
# Text: Argumentative Thesis, Confidence: 0.80
# Text: Narrative Thesis, Confidence: 0.70
# Text: Descriptive Thesis, Confidence: 0.87
# Text: Comparative Thesis, Confidence: 0.83
# Text: Persuasive Thesis, Confidence: 0.99
# Text: Research Thesis, Confidence: 0.97
# Text: Reflective Thesis, Confidence: 0.93
# Text: Experimental Thesis, Confidence: 0.99
# Text: EXx, Confidence: 0.35
# Text: Examples com, Confidence: 0.84
# Text: THESIS, Confidence: 1.00

# %%
# 결과 시각화
image = cv2.imread(image_path)
for bbox, text, conf in results:
    (top_left, top_right, bottom_right, bottom_left) = bbox
    top_left = tuple(map(int, top_left))
    bottom_right = tuple(map(int, bottom_right))
    cv2.rectangle(image, top_left, bottom_right, (0, 255, 0), 2)
    cv2.putText(image, text, (top_left[0], top_left[1] - 10),
                cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 0, 255), 2)

plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# output format
for r in results:
    print(r)
# Out:
# ([[np.int32(62), np.int32(52)], [np.int32(302), np.int32(52)], [np.int32(302), np.int32(128)], [np.int32(62), np.int32(128)]], 'Thesis', np.float64(0.884126892373304))
# ([[np.int32(671), np.int32(87)], [np.int32(800), np.int32(87)], [np.int32(800), np.int32(136)], [np.int32(671), np.int32(136)]], 'Iypes:', np.float64(0.9820757876876738))
# ([[np.int32(66), np.int32(122)], [np.int32(182), np.int32(122)], [np.int32(182), np.int32(152)], [np.int32(66), np.int32(152)]], '["THEE-sis_', np.float64(0.9454710268180434))
# ([[np.int32(189), np.int32(127)], [np.int32(203), np.int32(127)], [np.int32(203), np.int32(149)], [np.int32(189), np.int32(149)]], '1', np.float64(0.8481775485785334))
# ([[np.int32(705), np.int32(149)], [np.int32(949), np.int32(149)], [np.int32(949), np.int32(189)], [np.int32(705), np.int32(189)]], 'Expository Thesis', np.float64(0.8285354814163687))
